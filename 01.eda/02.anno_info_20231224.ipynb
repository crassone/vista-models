# %% [markdown]
# # アノテーションした結果の統計情報を可視化します。
# 2023/12/24時点の結果になります。
# `crassone-analysis/data/annotation/`にlabelstudioからexportしたjsonファイルを置いてください。

# %%
import glob
import json
import os
import pandas as pd

# %%
pattern_date = '2023-12-24'

# %%
anno_info_dir = f'{"/".join(os.getcwd().split("/")[:-2])}/data/annotation'
anno_info_path = [path for path in glob.glob(f'{anno_info_dir}/*.json') if pattern_date in path][0]
anno_dict = json.load(open(anno_info_path))

# %%
anno_dict_not_cancelled = [anno for anno in anno_dict if not anno['annotations'][0]['was_cancelled']]

# %%
labels_list = [
    "helmet",
    "unsafe-helmet (no chin strap)",
    "unsafe-helmet (inadequate covering)",
    "no-helmet",
    "helmet unknown (small)",
    "helmet unknown (occlusion)",
    "safety belt",
    "person",
    "person in high place",
]

# %%
labels_count_by_image = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image[key] += int(value)

# %%
labels_count_by_bbox = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                labels_count_by_bbox[label] += 1

# %%
labels_count_by_image_in_fixed_camera = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'fixed-point-camera' in anno_by_img['data']['image']:
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_fixed_camera[key] += int(value)

# %%
labels_count_by_image_in_fixed_camera_eval = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'evaluation' in anno_by_img['data']['image']:
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_fixed_camera_eval[key] += int(value)

# %%
labels_count_by_image_in_learning = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'for-learning' in anno_by_img['data']['image']:
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_learning[key] += int(value)

# %%
labels_count_by_image_in_indoor = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'fixed-point-camera' in anno_by_img['data']['image']:
        continue
    if not 'indoor' in anno_by_img['data']['image']:
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_indoor[key] += int(value)

# %%
labels_count_by_image_in_outdoor = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'fixed-point-camera' in anno_by_img['data']['image']:
        continue
    if not 'outdoor' in anno_by_img['data']['image']:
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_outdoor[key] += int(value)

# %%
labels_count_by_image_in_learning_indoor = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'for-learning' in anno_by_img['data']['image']:
        continue
    if (
        '2023-11-19-omaezaki-500' in anno_by_img['data']['image'] or 
        '2023-11-23-mie-safetybelt' in anno_by_img['data']['image']
    ):
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_learning_indoor[key] += int(value)

# %%
labels_count_by_image_in_learning_outdoor = {key: 0 for key in labels_list}
for anno_by_img in anno_dict_not_cancelled:
    if not 'for-learning' in anno_by_img['data']['image']:
        continue
    if not (
        '2023-11-19-omaezaki-500' in anno_by_img['data']['image'] or 
        '2023-11-23-mie-safetybelt' in anno_by_img['data']['image']
    ):
        continue
    label_bool_by_img = {key: False for key in labels_list}
    for annotation in anno_by_img['annotations']:
        for result in annotation['result']:
            labels = result['value']['rectanglelabels']
            for label in labels:
                label_bool_by_img[label] = True
    for key, value in label_bool_by_img.items():
        labels_count_by_image_in_learning_outdoor[key] += int(value)

# %%
# 全画像枚数の集計
anno_count_df = pd.DataFrame(labels_count_by_image, index=["画像枚数"]).T
anno_count_df.loc["no person"] = len([anno for anno in anno_dict_not_cancelled if not anno['annotations'][0]['result']])
anno_count_df.loc["アノテーション合計"] = len(anno_dict_not_cancelled)
anno_count_df.loc["アノテーション合計(キャンセル含む)"] = len(anno_dict)

# 全画像のbboxの集計
anno_count_bbox_df = pd.DataFrame(labels_count_by_bbox, index=["バウンディングボックス数"]).T
anno_count_bbox_df.loc["アノテーション合計"] = anno_count_bbox_df["バウンディングボックス数"].sum()

# 固定カメラの画像枚数の集計
anno_count_fixed_camera_df = pd.DataFrame(labels_count_by_image_in_fixed_camera, index=["画像枚数-固定カメラ"]).T
anno_count_fixed_camera_df.loc["no person"] = len(
    [anno for anno in anno_dict_not_cancelled if 'fixed-point-camera' in anno['data']['image'] and not anno['annotations'][0]['result']]
)
anno_count_fixed_camera_df.loc["アノテーション合計"] = len(
    [anno for anno in anno_dict_not_cancelled if 'fixed-point-camera' in anno['data']['image']]
)
anno_count_fixed_camera_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [anno for anno in anno_dict if 'fixed-point-camera' in anno['data']['image']]
)

# 固定カメラの評価用画像枚数の集計
anno_count_fixed_camera_eval_df = pd.DataFrame(labels_count_by_image_in_fixed_camera_eval, index=["画像枚数-固定カメラ評価用"]).T
anno_count_fixed_camera_eval_df.loc["no person"] = len(
    [anno for anno in anno_dict_not_cancelled if 'evaluation' in anno['data']['image'] and not anno['annotations'][0]['result']]
)
anno_count_fixed_camera_eval_df.loc["アノテーション合計"] = len(
    [anno for anno in anno_dict_not_cancelled if 'evaluation' in anno['data']['image']]
)
anno_count_fixed_camera_eval_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [anno for anno in anno_dict if 'evaluation' in anno['data']['image']]
)

# 学習用の画像枚数の集計
anno_count_learning_df = pd.DataFrame(labels_count_by_image_in_learning, index=["画像枚数-学習用"]).T
anno_count_learning_df.loc["no person"] = len(
    [anno for anno in anno_dict_not_cancelled if 'for-learning' in anno['data']['image'] and not anno['annotations'][0]['result']]
)
anno_count_learning_df.loc["アノテーション合計"] = len(
    [anno for anno in anno_dict_not_cancelled if 'for-learning' in anno['data']['image']]
)
anno_count_learning_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [anno for anno in anno_dict if 'for-learning' in anno['data']['image']]
)

# 屋内固定カメラの画像枚数の集計
anno_count_indoor_df = pd.DataFrame(labels_count_by_image_in_indoor, index=["画像枚数-固定カメラ-屋内"]).T
anno_count_indoor_df.loc["no person"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'fixed-point-camera' in anno['data']['image'] and 'indoor' in anno['data']['image'] and not anno['annotations'][0]['result']]
)
anno_count_indoor_df.loc["アノテーション合計"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'fixed-point-camera' in anno['data']['image'] and 'indoor' in anno['data']['image']
    ]
)
anno_count_indoor_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [
        anno for anno in anno_dict 
        if 'fixed-point-camera' in anno['data']['image'] and 'indoor' in anno['data']['image']
    ]
)

# 屋外固定カメラの画像枚数の集計
anno_count_outdoor_df = pd.DataFrame(labels_count_by_image_in_outdoor, index=["画像枚数-固定カメラ-屋外"]).T
anno_count_outdoor_df.loc["no person"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'fixed-point-camera' in anno['data']['image'] and 'outdoor' in anno['data']['image'] and not anno['annotations'][0]['result']]
)
anno_count_outdoor_df.loc["アノテーション合計"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'fixed-point-camera' in anno['data']['image'] and 'outdoor' in anno['data']['image']
    ]
)
anno_count_outdoor_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [
        anno for anno in anno_dict 
        if 'fixed-point-camera' in anno['data']['image'] and 'outdoor' in anno['data']['image']
    ]
)

# 屋内学習用の画像枚数の集計
anno_count_learning_indoor_df = pd.DataFrame(labels_count_by_image_in_learning_indoor, index=["画像枚数-学習用-屋内"]).T
anno_count_learning_indoor_df.loc["no person"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'for-learning' in anno['data']['image'] 
        and '2023-11-19-omaezaki-500' not in anno['data']['image'] 
        and '2023-11-23-mie-safetybelt' not in anno['data']['image'] 
        and not anno['annotations'][0]['result']
    ]
)
anno_count_learning_indoor_df.loc["アノテーション合計"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'for-learning' in anno['data']['image'] 
        and '2023-11-19-omaezaki-500' not in anno['data']['image'] 
        and '2023-11-23-mie-safetybelt' not in anno['data']['image']
    ]
)
anno_count_learning_indoor_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [
        anno for anno in anno_dict 
        if 'for-learning' in anno['data']['image'] 
        and '2023-11-19-omaezaki-500' not in anno['data']['image'] 
        and '2023-11-23-mie-safetybelt' not in anno['data']['image']
    ]
)

# 屋外学習用の画像枚数の集計
anno_count_learning_outdoor_df = pd.DataFrame(labels_count_by_image_in_learning_outdoor, index=["画像枚数-学習用-屋外"]).T
anno_count_learning_outdoor_df.loc["no person"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'for-learning' in anno['data']['image'] 
        and (
            '2023-11-19-omaezaki-500' in anno['data']['image'] or 
            '2023-11-23-mie-safetybelt' in anno['data']['image']
        ) 
        and not anno['annotations'][0]['result']
    ]
)
anno_count_learning_outdoor_df.loc["アノテーション合計"] = len(
    [
        anno for anno in anno_dict_not_cancelled 
        if 'for-learning' in anno['data']['image'] 
        and (
            '2023-11-19-omaezaki-500' in anno['data']['image'] or 
            '2023-11-23-mie-safetybelt' in anno['data']['image']
        )
    ]
)
anno_count_learning_outdoor_df.loc["アノテーション合計(キャンセル含む)"] = len(
    [
        anno for anno in anno_dict 
        if 'for-learning' in anno['data']['image'] 
        and (
            '2023-11-19-omaezaki-500' in anno['data']['image'] or 
            '2023-11-23-mie-safetybelt' in anno['data']['image']
        )
    ]
)

# %%
anno_count_whole_df = pd.concat([
    anno_count_df,
    anno_count_bbox_df,
    anno_count_fixed_camera_df,
    anno_count_learning_df,
    anno_count_fixed_camera_eval_df,
], axis=1)
anno_count_whole_df
# Out:
#                                      画像枚数  バウンディングボックス数  画像枚数-固定カメラ  画像枚数-学習用  \
# helmet                                854         858.0          38       808
# unsafe-helmet (no chin strap)         416         416.0          34       381
# unsafe-helmet (inadequate covering)   563         663.0         365       169
# no-helmet                             395         525.0         128       257
# helmet unknown (small)                212         222.0         108        89
# helmet unknown (occlusion)            715         774.0         252       439
# safety belt                          1434        1442.0           0      1427
# person                               2637        3355.0         590      2010
# person in high place                  138         158.0          80        30
# no person                             124           NaN          81        10
# アノテーション合計                            2863        8413.0         723      2050
# アノテーション合計(キャンセル含む)                   7394           NaN        2632      4296
#
#                                      画像枚数-固定カメラ評価用
# helmet                                           8
# unsafe-helmet (no chin strap)                    1
# unsafe-helmet (inadequate covering)             29
# no-helmet                                       10
# helmet unknown (small)                          15
# helmet unknown (occlusion)                      24
# safety belt                                      7
# person                                          37
# person in high place                            28
# no person                                       33
# アノテーション合計                                       90
# アノテーション合計(キャンセル含む)                             466

# %%
anno_count_whole_for_learning_df = pd.concat([
    anno_count_df,
    anno_count_bbox_df,
    anno_count_fixed_camera_df,
    anno_count_learning_outdoor_df,
    anno_count_learning_indoor_df,
    anno_count_fixed_camera_eval_df,
], axis=1)
anno_count_whole_for_learning_df
# Out:
#                                      画像枚数  バウンディングボックス数  画像枚数-固定カメラ  \
# helmet                                854         858.0          38
# unsafe-helmet (no chin strap)         416         416.0          34
# unsafe-helmet (inadequate covering)   563         663.0         365
# no-helmet                             395         525.0         128
# helmet unknown (small)                212         222.0         108
# helmet unknown (occlusion)            715         774.0         252
# safety belt                          1434        1442.0           0
# person                               2637        3355.0         590
# person in high place                  138         158.0          80
# no person                             124           NaN          81
# アノテーション合計                            2863        8413.0         723
# アノテーション合計(キャンセル含む)                   7394           NaN        2632
#
#                                      画像枚数-学習用-屋外  画像枚数-学習用-屋内  画像枚数-固定カメラ評価用
# helmet                                       169          639              8
# unsafe-helmet (no chin strap)                275          106              1
# unsafe-helmet (inadequate covering)          168            1             29
# no-helmet                                     47          210             10
# helmet unknown (small)                        36           53             15
# helmet unknown (occlusion)                   111          328             24
# safety belt                                  366         1061              7
# person                                       752         1258             37
# person in high place                          30            0             28
# no person                                      0           10             33
# アノテーション合計                                    782         1268             90
# アノテーション合計(キャンセル含む)                          2654         1642            466

# %%
anno_count_fixed_camera_df = pd.concat([
    anno_count_df,
    anno_count_fixed_camera_df,
    anno_count_indoor_df,
    anno_count_outdoor_df,
], axis=1)
anno_count_fixed_camera_df
# Out:
#                                      画像枚数  画像枚数-固定カメラ  画像枚数-固定カメラ-屋内  \
# helmet                                854          38              5
# unsafe-helmet (no chin strap)         416          34              6
# unsafe-helmet (inadequate covering)   563         365            125
# no-helmet                             395         128              8
# helmet unknown (small)                212         108             13
# helmet unknown (occlusion)            715         252             89
# safety belt                          1434           0              0
# person                               2637         590            148
# person in high place                  138          80              0
# no person                             124          81              9
# アノテーション合計                            2863         723            157
# アノテーション合計(キャンセル含む)                   7394        2632            232
#
#                                      画像枚数-固定カメラ-屋外
# helmet                                          33
# unsafe-helmet (no chin strap)                   28
# unsafe-helmet (inadequate covering)            240
# no-helmet                                      120
# helmet unknown (small)                          95
# helmet unknown (occlusion)                     163
# safety belt                                      0
# person                                         442
# person in high place                            80
# no person                                       72
# アノテーション合計                                      566
# アノテーション合計(キャンセル含む)                            2400

# %%
anno_count_learning_df = pd.concat([
    anno_count_df,
    anno_count_learning_df,
    anno_count_learning_indoor_df,
    anno_count_learning_outdoor_df,
], axis=1)
anno_count_learning_df
# Out:
#                                      画像枚数  画像枚数-学習用  画像枚数-学習用-屋内  画像枚数-学習用-屋外
# helmet                                854       808          639          169
# unsafe-helmet (no chin strap)         416       381          106          275
# unsafe-helmet (inadequate covering)   563       169            1          168
# no-helmet                             395       257          210           47
# helmet unknown (small)                212        89           53           36
# helmet unknown (occlusion)            715       439          328          111
# safety belt                          1434      1427         1061          366
# person                               2637      2010         1258          752
# person in high place                  138        30            0           30
# no person                             124        10           10            0
# アノテーション合計                            2863      2050         1268          782
# アノテーション合計(キャンセル含む)                   7394      4296         1642         2654
